# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:
data = pd.read_csv('D:\DataScience\kc_house_data.csv')
data.head()

#Hint: read_csv(), head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# Our dataset using Pandas and create a DataFrame.

# %%
#b) 
house_categorical_df = data.select_dtypes('category')
house_numerical_df = data.select_dtypes('number')

# %%
#c)
#Your code:
my_features = ['bathrooms', 'bedrooms', 'floors', 'lat', 'long', 'price', 'sqft_above', 'sqft_basement', 'sqft_living', 'sqft_living15', 'sqft_lot', 'sqft_lot15', 'yr_built', 'yr_renovated']
data[my_features].describe(include = 'all')

#Hint: Function describe()
# Out:
#           bathrooms      bedrooms        floors           lat          long  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       2.114757      3.370842      1.494309     47.560053   -122.213896
# std        0.770163      0.930062      0.539989      0.138564      0.140828
# min        0.000000      0.000000      1.000000     47.155900   -122.519000
# 25%        1.750000      3.000000      1.000000     47.471000   -122.328000
# 50%        2.250000      3.000000      1.500000     47.571800   -122.230000
# 75%        2.500000      4.000000      2.000000     47.678000   -122.125000
# max        8.000000     33.000000      3.500000     47.777600   -121.315000
#
#               price    sqft_above  sqft_basement   sqft_living  sqft_living15  \
# count  2.161300e+04  21613.000000   21613.000000  21613.000000   21613.000000
# mean   5.400881e+05   1788.390691     291.509045   2079.899736    1986.552492
# ...

# %% [markdown]
# There is some information we can interpret here, for example house prices:
#
# The mean value of homes of 540,088 is greater than the median of 450,000. This is an indication that the response variable is positively skewed. When this happens, regressing the log of price usually provides a better fitting, compared to the original price;
# The maximum house price is listed as 7,700.000 and the minimum price is 75,000.
#
# Most of them make sense because we can analyze them.

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.scatter(x = data['sqft_living'], y = data['price'])
plt.ticklabel_format(axis='both', style='plain')
plt.xlabel('sqft living'), plt.ylabel('price') 

#Hint plt.scatter
# Out:
# (Text(0.5, 0, 'sqft living'), Text(0, 0.5, 'price'))

# %% [markdown]
# Here we can see the ratio of price to square meters of the house. The cheapest houses have sq footage between 1000 to 3000 and their price is between around $500.000 - $1.500.000.

# %%
#b)
#Your code:
plt.scatter(x=data['grade'], y=data['price'])
plt.ticklabel_format(axis='both', style='plain')
plt.xlabel('grade'), plt.ylabel('price')
# Out:
# (Text(0.5, 0, 'grade'), Text(0, 0.5, 'price'))

# %% [markdown]
# As expected, the higher the class of the apartment, the bigger the price. As the grades of the houses hit the extremes (min and max) we can see that their number drastically declines.

# %%
#c)
#Your code:
plt.scatter(x=data['zipcode'], y=data['price'])
plt.ticklabel_format(axis='both', style='plain')
plt.xlabel('zipcode'), plt.ylabel('price')
# Out:
# (Text(0.5, 0, 'zipcode'), Text(0, 0.5, 'price'))

# %% [markdown]
# Here we can see the ratio of price to zip code of the house.

# %%
#Your code:
plt.scatter(x = data['long'], y = data['lat'], c = data['grade'], s = 25)
plt.ylabel('lattitude'), plt.xlabel('longitude')
# Out:
# (Text(0, 0.5, 'lattitude'), Text(0.5, 0, 'longitude'))

# %% [markdown]
# In this graph we can see how good apartments are distributed over the city. Using apartments coordinates (longitude and lattitude) to show where apartments of good grade are located.

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
data.boxplot(column='price', by='grade')
plt.title(''), plt.suptitle(''), plt.ylabel('price')
plt.ticklabel_format(axis='y', style='plain')
plt.grid(b=None)
#Hint: plt.boxplot

# %% [markdown]
# This boxplot is useful to check the outliers in prices. As we can see, as the house grade increases, its price also increases. Also the variability in price increases as house grade increases.

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:
mosaic(data, ['bedrooms', 'floors'])
# Out:
# (<Figure size 1080x720 with 3 Axes>,
#  {('3', '1.0'): (0.0, 0.0, 0.4288124984177063, 0.5461699684946868),
#   ('3', '2.0'): (0.0,
#    0.5494486570192769,
#    0.4288124984177063,
#    0.3121829444118118),
#   ('3', '1.5'): (0.0,
#    0.864910289955679,
#    0.4288124984177063,
#    0.0786965344155498),
#   ('3', '3.0'): (0.0,
#    0.9468855128958189,
#    0.4288124984177063,
#    0.040549741015645895),
#   ('3', '2.5'): (0.0,
#    0.990713942436055,
#    0.4288124984177063,
#    0.005606877770064615),
#   ('3', '3.5'): (0.0,
#    0.9995995087307098,
#    0.4288124984177063,
#    0.0004004912692902751),
#   ('2', '1.0'): (0.43352947954978177,
#    0.0,
#    0.12047256673787353,
#    0.6952957947255881),
#   ('2', '2.0'): (0.43352947954978177,
#    0.6985744832501782,
#    0.12047256673787353,
#    0.17712045616535993),
#   ('2', '1.5'): (0.43352947954978177,
#    0.8789736279401283,
#    0.12047256673787353,
#    0.06486101211689241),
#   ('2', '3.0'): (0.43352947954978177,
# ...

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
sort_rooms = data[(data['bathrooms'] == 2) & (data['bedrooms'] == 3) & (data['floors'] == 2)]
sort_rooms.drop(['date'], axis = 1).describe(include = 'all')
#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %% [markdown]
# We can analyze this output, like in a task 1.c) using fulfilling above constraints.

# %%
#b)
#Your code:
sort_rooms = data[(data['bathrooms'] == 2) & (data['bedrooms'] == 3) & (data['floors'] == 2)]
plt.scatter(x=data['grade'], y=data['price'], s = 5, color = 'black')
plt.ticklabel_format(axis='both', style='plain')
plt.xlabel('grade'), plt.ylabel('price') 
plt.scatter(x=sort_rooms['grade'], y=sort_rooms['price'], s = 15, alpha=0.75, color = 'y')
plt.rcParams["figure.figsize"] = (15,10)

# %% [markdown]
# Here we can see, that the most houses are in good grades and are not close to hitting the given top prices

# %%
#c)
#Your code:
sort_rooms = data[(data['bathrooms'] == 2) & (data['bedrooms'] == 3) & (data['floors'] == 2)]
sort_rooms.loc[(sort_rooms['price'] / sort_rooms['sqft_living']).sort_values().index].head()

#Hint: .loc, .sort_values(), .index
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000  260000.0         3        2.0
# 11258  7937600262  20140710T000000  379900.0         3        2.0
# 19880  3832050860  20150319T000000  210000.0         3        2.0
# 16014  5104450440  20141113T000000  252500.0         3        2.0
# 20906  3355400242  20141028T000000  274900.0         3        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9704          2710      5000     2.0           0     0  ...      6
# 11258         3110     44967     2.0           0     0  ...      9
# 19880         1580      4961     2.0           0     0  ...      7
# 16014         1810     10684     2.0           0     0  ...      8
# 20906         1936      6612     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9704         2710              0      1951             0    98126  47.5188
# ...

# %% [markdown]
# In this case we found the best price to footage ratio for 5 apartments.
